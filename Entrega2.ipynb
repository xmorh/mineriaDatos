# %% [markdown]
# ## ET Entrega 1
# # Caso Análisis de Condiciones Climáticas en Australia
#
# * Maura Ruminot
# * Paula Romero

# %%
# Importación de librerías
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("australiaEDA.csv")
data.head()
# Out:
#    Unnamed: 0        Date Location  MinTemp  MaxTemp  Rainfall WindGustDir  \
# 0           0  2008-12-01   Albury     13.4     22.9       0.6           W
# 1           1  2008-12-02   Albury      7.4     25.1       0.0         WNW
# 2           2  2008-12-03   Albury     12.9     25.7       0.0         WSW
# 3           3  2008-12-04   Albury      9.2     28.0       0.0          NE
# 4           4  2008-12-05   Albury     17.5     32.3       1.0           W
#
#   WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  Cloud9am  Cloud3pm  \
# 0          44.0          W        WNW  ...       1007.1       8.0       8.0
# 1          44.0        NNW        WSW  ...       1007.8       8.0       8.0
# 2          46.0          W        WSW  ...       1008.7       8.0       2.0
# 3          24.0         SE          E  ...       1012.8       8.0       8.0
# 4          41.0        ENE         NW  ...       1006.0       7.0       8.0
#
# ...

# %%
print(data['Location'].unique())
# Out:
# ['Albury' 'BadgerysCreek' 'Cobar' 'CoffsHarbour' 'Moree' 'Newcastle'
#  'NorahHead' 'NorfolkIsland' 'Penrith' 'Richmond' 'Sydney' 'SydneyAirport'
#  'WaggaWagga' 'Williamtown' 'Wollongong' 'Canberra' 'Tuggeranong'
#  'MountGinini' 'Ballarat' 'Bendigo' 'Sale' 'MelbourneAirport' 'Melbourne'
#  'Mildura' 'Nhil' 'Portland' 'Watsonia' 'Dartmoor' 'Brisbane' 'Cairns'
#  'GoldCoast' 'Townsville' 'Adelaide' 'MountGambier' 'Nuriootpa' 'Woomera'
#  'Albany' 'Witchcliffe' 'PearceRAAF' 'PerthAirport' 'Perth' 'SalmonGums'
#  'Walpole' 'Hobart' 'Launceston' 'AliceSprings' 'Darwin' 'Katherine'
#  'Uluru']

# %%
# transformando en dummies --> one.hot.enconding
data = pd.get_dummies(data, columns=["Location"])
data.head()
# Out:
#    Unnamed: 0        Date  MinTemp  MaxTemp  Rainfall WindGustDir  \
# 0           0  2008-12-01     13.4     22.9       0.6           W
# 1           1  2008-12-02      7.4     25.1       0.0         WNW
# 2           2  2008-12-03     12.9     25.7       0.0         WSW
# 3           3  2008-12-04      9.2     28.0       0.0          NE
# 4           4  2008-12-05     17.5     32.3       1.0           W
#
#   WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Location_Townsville  \
# 0          44.0          W        WNW          20.0  ...                    0
# 1          44.0        NNW        WSW           4.0  ...                    0
# 2          46.0          W        WSW          19.0  ...                    0
# 3          24.0         SE          E          11.0  ...                    0
# 4          41.0        ENE         NW           7.0  ...                    0
#
#    Location_Tuggeranong  Location_Uluru  Location_WaggaWagga  \
# ...

# %%
# Transformar la columna Location en variables dummy
data_dummies = pd.get_dummies(data, columns=['Location'])

# Revisar las primeras filas del DataFrame transformado
print("\nPrimeras filas del DataFrame transformado:")
print(data_dummies.head())

# Verificar las columnas dummy creadas
print("\nColumnas dummy creadas:")
print(data_dummies.columns)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 # Transformar la columna Location en variables dummy
# ----> 2 data_dummies = pd.get_dummies(data, columns=['Location'])
#       4 # Revisar las primeras filas del DataFrame transformado
#       5 print("\nPrimeras filas del DataFrame transformado:")
#
# File c:\Users\maura\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\reshape.py:931, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     929     raise TypeError("Input must be a list-like for parameter `columns`")
#     930 else:
# --> 931     data_to_encode = data[columns]
#     933 # validate prefixes and separator to avoid silently dropping cols
#     934 def check_len(item, name):
#
# ...
